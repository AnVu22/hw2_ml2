# %% [markdown]
# Vũ Đức An 11204235

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_openml
import warnings

warnings.filterwarnings('ignore')

# %%
# Load the dataset
mnist = fetch_openml('mnist_784')
df = mnist.data
label = mnist.target

# %%
# Scale the data
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
# Perform PCA
pca = PCA(n_components=2, random_state=0)
pca_res = pca.fit_transform(df_scaled)

# %%
# Plot PCA results
plt.figure(figsize=(16,10))
sns.scatterplot(x=pca_res[:,0], y=pca_res[:,1], hue=label, palette=sns.color_palette('bright', 10), legend='full')
plt.title('PCA')
plt.show()

# %%
# Perform t-SNE
tsne = TSNE(n_components=2, random_state=0)
tsne_res = tsne.fit_transform(df_scaled)

# %%
# Plot t-SNE results
plt.figure(figsize=(16,10))
sns.scatterplot(x=tsne_res[:,0], y=tsne_res[:,1], hue=label, palette=sns.color_palette('bright', 10), legend='full')
plt.title('t-SNE')
plt.show()
